# %%
import matplotlib.pyplot as plt
import pandas as pd
import zipfile
import os

zip_path = "C:\\Users\\Vinicius\\Documents\\Analise de dados\\2026\\0001-0001 - Air Jordan Sneaker Market & Resale\\air-jordan-sales-analysis\\data\\raw\\air-jordan-sneaker-market-and-resale-data2023-2026.zip"
extract_path = "data/raw/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extração concluída")
# Out:
# Extração concluída

# %%
df = pd.read_csv("data/raw/jordan_market_dataset_2026.csv")
df.head()
# Out:
#   Transaction_ID   Sale_Date           Shoe_Model Colorway  \
# 0     TRX-100001  2024-10-23  Air Jordan 11 Retro     Sail
# 1     TRX-100002  2023-10-23    Air Jordan 1 High    Mocha
# 2     TRX-100003  2023-11-13   Air Jordan 4 Retro  Concord
# 3     TRX-100004  2024-02-01   Air Jordan 4 Retro    Mocha
# 4     TRX-100005  2023-05-29     Air Jordan 1 Low    Mocha
#
#                Condition  Retail_Price_USD  Resale_Price_USD  Sales_Channel  \
# 0                   Used               225            194.67           GOAT
# 1  Deadstock (Brand New)               185            230.46         StockX
# 2  Deadstock (Brand New)               212            270.37  kick hub 2026
# 3                   Used               223            180.43  Stadium Goods
# 4                   Used               137            117.43  kick hub 2026
#
#    Days_in_Inventory  Profit_Margin_USD
# 0                 13             -30.33
# 1                 10              45.46
# 2                 33              58.37
# 3                 60             -42.57
# 4                 30             -19.57

# %%
df.describe()
# Out:
#        Retail_Price_USD  Resale_Price_USD  Days_in_Inventory  \
# count       5000.000000       5000.000000        5000.000000
# mean         191.172400        273.230512          22.472600
# std           37.099191        167.237989          17.741449
# min          110.000000         55.910000           1.000000
# 25%          175.000000        148.487500           8.000000
# 50%          205.000000        226.160000          14.000000
# 75%          221.000000        333.950000          37.000000
# max          230.000000        804.580000          60.000000
#
#        Profit_Margin_USD
# count        5000.000000
# mean           82.058112
# std           159.073822
# min          -114.350000
# 25%           -37.122500
# 50%            35.270000
# 75%           153.090000
# max           574.580000

# %%
df.isnull().sum()
# Out:
# Transaction_ID       0
# Sale_Date            0
# Shoe_Model           0
# Colorway             0
# Condition            0
# Retail_Price_USD     0
# Resale_Price_USD     0
# Sales_Channel        0
# Days_in_Inventory    0
# Profit_Margin_USD    0
# dtype: int64

# %%
print("Duplicatas:", df.duplicated().sum())
# Out:
# Duplicatas: 0

# %%
df.shape
# Out:
# (5000, 10)

# %%
df.dtypes
# Out:
# Transaction_ID           str
# Sale_Date                str
# Shoe_Model               str
# Colorway                 str
# Condition                str
# Retail_Price_USD       int64
# Resale_Price_USD     float64
# Sales_Channel            str
# Days_in_Inventory      int64
# Profit_Margin_USD    float64
# dtype: object

# %%
df.hist(figsize=(12, 10))
plt.suptitle("Distribuição das Variáveis Numéricas", fontsize=16)
plt.tight_layout()
plt.savefig("../outputs/figures/distribuicao_variaveis.png")
plt.show()

# %% [markdown]
# ## Plotado os primeiros gráficos
